# %%
import pandas as pd

# %%
pd.__version__
# Out:
# '2.3.3'

# %%
df = pd.read_parquet('/workspaces/mlops-zoomcamp-leo/01-intro/yellow_tripdata_2025-01.parquet', engine='fastparquet')

# %%
df.head()
# Out:
#    VendorID tpep_pickup_datetime tpep_dropoff_datetime  passenger_count  \
# 0         1  2025-01-01 00:18:38   2025-01-01 00:26:59              1.0
# 1         1  2025-01-01 00:32:40   2025-01-01 00:35:13              1.0
# 2         1  2025-01-01 00:44:04   2025-01-01 00:46:01              1.0
# 3         2  2025-01-01 00:14:27   2025-01-01 00:20:01              3.0
# 4         2  2025-01-01 00:21:34   2025-01-01 00:25:06              3.0
#
#    trip_distance  RatecodeID store_and_fwd_flag  PULocationID  DOLocationID  \
# 0           1.60         1.0                  N           229           237
# 1           0.50         1.0                  N           236           237
# 2           0.60         1.0                  N           141           141
# 3           0.52         1.0                  N           244           244
# 4           0.66         1.0                  N           244           116
#
#    payment_type  fare_amount  extra  mta_tax  tip_amount  tolls_amount  \
# ...

# %%
import sklearn

# %%
sklearn.__version__
# Out:
# '1.8.0'

# %%
df.tpep_pickup_datetime - df.tpep_dropoff_datetime
# Out:
# 0         -1 days +23:51:39
# 1         -1 days +23:57:27
# 2         -1 days +23:58:03
# 3         -1 days +23:54:26
# 4         -1 days +23:56:28
#                  ...
# 3475221   -1 days +23:45:19
# 3475222   -1 days +23:33:02
# 3475223   -1 days +23:43:58
# 3475224   -1 days +23:39:42
# 3475225   -1 days +23:49:15
# Length: 3475226, dtype: timedelta64[us]

# %%
pd.to_datetime(df.tpep_pickup_datetime)
pd.to_datetime(df.tpep_dropoff_datetime)
# Out:
# 0         2025-01-01 00:26:59
# 1         2025-01-01 00:35:13
# 2         2025-01-01 00:46:01
# 3         2025-01-01 00:20:01
# 4         2025-01-01 00:25:06
#                   ...
# 3475221   2025-01-31 23:16:29
# 3475222   2025-02-01 00:17:27
# 3475223   2025-01-31 23:43:01
# 3475224   2025-01-31 23:34:52
# 3475225   2025-02-01 00:07:27
# Name: tpep_dropoff_datetime, Length: 3475226, dtype: datetime64[us]

# %%
df['duration'] = df.tpep_dropoff_datetime - df.tpep_pickup_datetime
df.duration.apply(lambda td: td.total_seconds() / 60)   # transform seconds to min to each element
# Out:
# 0           8.350000
# 1           2.550000
# 2           1.950000
# 3           5.566667
# 4           3.533333
#              ...
# 3475221    14.683333
# 3475222    26.966667
# 3475223    16.033333
# 3475224    20.300000
# 3475225    10.750000
# Name: duration, Length: 3475226, dtype: float64

# %%
df
# Out:
#          VendorID tpep_pickup_datetime tpep_dropoff_datetime  passenger_count  \
# 0               1  2025-01-01 00:18:38   2025-01-01 00:26:59              1.0
# 1               1  2025-01-01 00:32:40   2025-01-01 00:35:13              1.0
# 2               1  2025-01-01 00:44:04   2025-01-01 00:46:01              1.0
# 3               2  2025-01-01 00:14:27   2025-01-01 00:20:01              3.0
# 4               2  2025-01-01 00:21:34   2025-01-01 00:25:06              3.0
# ...           ...                  ...                   ...              ...
# 3475221         2  2025-01-31 23:01:48   2025-01-31 23:16:29              NaN
# 3475222         2  2025-01-31 23:50:29   2025-02-01 00:17:27              NaN
# 3475223         2  2025-01-31 23:26:59   2025-01-31 23:43:01              NaN
# 3475224         2  2025-01-31 23:14:34   2025-01-31 23:34:52              NaN
# 3475225         2  2025-01-31 23:56:42   2025-02-01 00:07:27              NaN
#
# ...

# %%
# Now check the distribution of the duration
